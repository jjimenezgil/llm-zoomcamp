# %% [markdown]
# # Homework: Orchestration
#
#
# ### Imports

# %%
import numpy as np

# %% [markdown]
# ## Q1. Running Mage
#
# After running all the specified commands, Mage is running in: http://localhost:6789/.

# %% [markdown]
# ![image.png](attachment:d8373269-5e49-4c49-9d55-da0cadee5cc2.png)

# %% [markdown]
# **Answer**: v0.9.72
#
# ## Q2. Reading the documents
#
# After generating and running the new ingestion block of type Custom Code, the version 1 of the FAQ doc was processed:

# %% [markdown]
# ![image.png](attachment:6c08c58e-5833-4e72-a218-608660fb04f3.png)

# %% [markdown]
# **Answer**: 1
#
# ## Q3. Chunking
#
# Once generated the customized chunking block that appends the id to each document, it is possible to check that the number of chunks in the output is 86.
# ![image.png](attachment:48094155-3b17-4ca5-aa29-bff2734e31fc.png)
#
# **Answer**: 86
#
# ## Q4. Export

# %%
from elasticsearch import Elasticsearch
es_client = Elasticsearch("http://localhost:9200")
es_client.info()
# Out:
# ObjectApiResponse({'name': '737274257ded', 'cluster_name': 'docker-cluster', 'cluster_uuid': 'HJ5_i0SkRwG0YreidRPU9A', 'version': {'number': '8.4.3', 'build_flavor': 'default', 'build_type': 'docker', 'build_hash': '42f05b9372a9a4a470db3b52817899b99a76ee73', 'build_date': '2022-10-04T07:17:24.662462378Z', 'build_snapshot': False, 'lucene_version': '9.3.0', 'minimum_wire_compatibility_version': '7.17.0', 'minimum_index_compatibility_version': '7.0.0'}, 'tagline': 'You Know, for Search'})
